# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df1 = pd.read_csv('data/mem_data.csv', parse_dates=['BIRTH_DT','RGST_DT','LAST_VST_DT']).sort_values('MEM_ID')
df1
# Out:
#         MEM_ID  M_STORE_ID   GENDER    BIRTH_DT BIRTH_SL ZIP_CD  \
# 10732      957         543        M         NaN        S      -
# 10731     1054         550  UNKNOWN   1968.9.28        L      -
# 10730     1067         550        M         NaN        S      -
# 10729     1068         543        M         NaN        S      -
# 10728     1078         550        M         NaN        S      -
# ...        ...         ...      ...         ...      ...    ...
# 4      1427418         997  UNKNOWN    1984.6.7        L      -
# 3      1427437         997        F  1986.12.18        L      -
# 2      1427447         825        M         NaN        S      -
# 1      1427464         997        F  1983.10.12        L      -
# 0      1427535       30017        M         NaN        S      -
#
#                       RGST_DT  VISIT_CNT  SALES_AMT             LAST_VST_DT  \
# 10732 2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 10731 2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# 10730 2006-02-04 11:51:08.233          1     199800 2006-09-16 21:05:11.383
# 10729 2006-02-04 11:51:08.233          9     115200 2007-11-07 18:08:30.587
# 10728 2006-02-04 11:51:08.233          5      85900 2007-09-28 19:14:38.900
# ...                       ...        ...        ...                     ...
# 4     2006-03-06 01:00:01.187          1      27900 2007-06-20 13:29:28.427
# 3     2006-03-06 01:00:01.187          3      47200 2006-11-04 15:52:08.970
# 2     2006-03-06 01:00:01.187          1      26100 2006-04-09 16:47:22.993
# 1     2006-03-06 01:00:01.187          2      36900 2006-10-04 17:37:16.957
# 0     2006-03-07 01:00:00.560          2      11000 2006-05-12 20:10:00.250
#
#        USABLE_PNT  USED_PNT  ACC_PNT  USABLE_INIT SMS
# 10732        1778         0     1778         1628   Y
# 10731       29158         0    29158          846   N
# 10730        4172         0     4172         3842   Y
# 10729        2442         0     2442          818   Y
# 10728        1718         0     1718         1010   Y
# ...           ...       ...      ...          ...  ..
# 4             558         0      558            0   Y
# 3             944         0      944            0   Y
# 2             522         0      522            0   Y
# 1             856         0      856            0   Y
# 0             338         0      338            0   Y
#
# [10733 rows x 15 columns]

# %%
df1['GENDER'].value_counts()
# Out:
# M          3759
# F          3754
# UNKNOWN    3220
# Name: GENDER, dtype: int64

# %%
df2 = pd.read_csv('data/mem_transaction.csv', parse_dates=['SELL_DT','MEMP_DT']).sort_values('MEM_ID')
df2
# Out:
#        STORE_ID    SELL_DT MEMP_STY         MEM_ID                 MEMP_DT  \
# 42968      2031 2007-08-30        O            957 2007-08-30 20:34:42.827
# 50554      3123 2007-08-17        O            957 2007-08-17 18:53:58.937
# 4852        554 2006-10-04        O            957 2006-10-04 23:55:07.240
# 4488        550 2006-05-02        O           1054 2006-05-02 13:20:35.643
# 4489        550 2006-05-02        O           1054 2006-05-02 13:21:19.907
# ...         ...        ...      ...            ...                     ...
# 26631      1156 2007-09-11        O  2007062900420 2007-09-11 18:03:43.783
# 58381      3930 2007-09-04        O  2007090300653 2007-09-04 20:43:55.593
# 58379      3930 2007-09-03        O  2007090300653 2007-09-03 19:02:57.693
# 58384      3930 2007-09-27        O  2007090300653 2007-09-27 19:39:58.250
# 58380      3930 2007-09-03        O  2007090300704 2007-09-03 19:33:07.850
#
#        SELL_AMT MEMP_TP
# 42968      3000       A
# 50554      3000       A
# 4852       1500       A
# 4488     134000       A
# 4489       8800       A
# ...         ...     ...
# 26631      6500       A
# 58381     52200       A
# 58379     41100       A
# 58384      2800       A
# 58380     23500       A
#
# [60049 rows x 7 columns]

# %%
df3 = pd.read_csv('data/store_info.csv')
df3
# Out:
#      STORE_ID  STORE_REGION
# 0         128             2
# 1         129             2
# 2         130            11
# 3         133            16
# 4         136            13
# ..        ...           ...
# 324     99981             4
# 325     99982             4
# 326     99983            10
# 327     99984             1
# 328     99985             3
#
# [329 rows x 2 columns]

# %%
merged = df1.merge(df2,how='left')
merged = merged.merge(df3,how='left')
merged
# Out:
#         MEM_ID  M_STORE_ID   GENDER    BIRTH_DT BIRTH_SL ZIP_CD  \
# 0          957         543        M         NaN        S      -
# 1          957         543        M         NaN        S      -
# 2          957         543        M         NaN        S      -
# 3         1054         550  UNKNOWN   1968.9.28        L      -
# 4         1054         550  UNKNOWN   1968.9.28        L      -
# ...        ...         ...      ...         ...      ...    ...
# 59690  1427447         825        M         NaN        S      -
# 59691  1427464         997        F  1983.10.12        L      -
# 59692  1427464         997        F  1983.10.12        L      -
# 59693  1427535       30017        M         NaN        S      -
# 59694  1427535       30017        M         NaN        S      -
#
#                       RGST_DT  VISIT_CNT  SALES_AMT             LAST_VST_DT  \
# 0     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 1     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 2     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 3     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# 4     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# ...                       ...        ...        ...                     ...
# 59690 2006-03-06 01:00:01.187          1      26100 2006-04-09 16:47:22.993
# 59691 2006-03-06 01:00:01.187          2      36900 2006-10-04 17:37:16.957
# 59692 2006-03-06 01:00:01.187          2      36900 2006-10-04 17:37:16.957
# 59693 2006-03-07 01:00:00.560          2      11000 2006-05-12 20:10:00.250
# 59694 2006-03-07 01:00:00.560          2      11000 2006-05-12 20:10:00.250
#
#        ...  ACC_PNT  USABLE_INIT  SMS  STORE_ID    SELL_DT  MEMP_STY  \
# 0      ...     1778         1628    Y      2031 2007-08-30         O
# 1      ...     1778         1628    Y      3123 2007-08-17         O
# 2      ...     1778         1628    Y       554 2006-10-04         O
# 3      ...    29158          846    N       550 2006-05-02         O
# 4      ...    29158          846    N       550 2006-05-02         O
# ...    ...      ...          ...  ...       ...        ...       ...
# 59690  ...      522            0    Y       825 2006-04-09         O
# 59691  ...      856            0    Y       997 2006-03-16         O
# 59692  ...      856            0    Y       997 2006-10-04         O
# 59693  ...      338            0    Y      3125 2006-05-07         O
# 59694  ...      338            0    Y      3125 2006-05-12         O
#
#                       MEMP_DT SELL_AMT MEMP_TP  STORE_REGION
# 0     2007-08-30 20:34:42.827     3000       A           NaN
# 1     2007-08-17 18:53:58.937     3000       A           NaN
# 2     2006-10-04 23:55:07.240     1500       A           NaN
# 3     2006-05-02 13:20:35.643   134000       A           NaN
# 4     2006-05-02 13:21:19.907     8800       A           NaN
# ...                       ...      ...     ...           ...
# 59690 2006-04-09 16:47:22.993    19700       A           NaN
# 59691 2006-03-16 16:36:49.443    24600       A           NaN
# 59692 2006-10-04 17:37:16.957    12300       A           NaN
# 59693 2006-05-07 21:51:33.703     5500       A           1.0
# 59694 2006-05-12 20:10:00.250     5500       A           1.0
#
# [59695 rows x 22 columns]

# %%
merged = merged.fillna(0)
merged
# Out:
#         MEM_ID  M_STORE_ID   GENDER    BIRTH_DT BIRTH_SL ZIP_CD  \
# 0          957         543        M           0        S      -
# 1          957         543        M           0        S      -
# 2          957         543        M           0        S      -
# 3         1054         550  UNKNOWN   1968.9.28        L      -
# 4         1054         550  UNKNOWN   1968.9.28        L      -
# ...        ...         ...      ...         ...      ...    ...
# 59690  1427447         825        M           0        S      -
# 59691  1427464         997        F  1983.10.12        L      -
# 59692  1427464         997        F  1983.10.12        L      -
# 59693  1427535       30017        M           0        S      -
# 59694  1427535       30017        M           0        S      -
#
#                       RGST_DT  VISIT_CNT  SALES_AMT             LAST_VST_DT  \
# 0     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 1     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 2     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 3     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# 4     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# ...                       ...        ...        ...                     ...
# 59690 2006-03-06 01:00:01.187          1      26100 2006-04-09 16:47:22.993
# 59691 2006-03-06 01:00:01.187          2      36900 2006-10-04 17:37:16.957
# 59692 2006-03-06 01:00:01.187          2      36900 2006-10-04 17:37:16.957
# 59693 2006-03-07 01:00:00.560          2      11000 2006-05-12 20:10:00.250
# 59694 2006-03-07 01:00:00.560          2      11000 2006-05-12 20:10:00.250
#
#        ...  ACC_PNT  USABLE_INIT  SMS  STORE_ID    SELL_DT  MEMP_STY  \
# 0      ...     1778         1628    Y      2031 2007-08-30         O
# 1      ...     1778         1628    Y      3123 2007-08-17         O
# 2      ...     1778         1628    Y       554 2006-10-04         O
# 3      ...    29158          846    N       550 2006-05-02         O
# 4      ...    29158          846    N       550 2006-05-02         O
# ...    ...      ...          ...  ...       ...        ...       ...
# 59690  ...      522            0    Y       825 2006-04-09         O
# 59691  ...      856            0    Y       997 2006-03-16         O
# 59692  ...      856            0    Y       997 2006-10-04         O
# 59693  ...      338            0    Y      3125 2006-05-07         O
# 59694  ...      338            0    Y      3125 2006-05-12         O
#
#                       MEMP_DT SELL_AMT MEMP_TP  STORE_REGION
# 0     2007-08-30 20:34:42.827     3000       A           0.0
# 1     2007-08-17 18:53:58.937     3000       A           0.0
# 2     2006-10-04 23:55:07.240     1500       A           0.0
# 3     2006-05-02 13:20:35.643   134000       A           0.0
# 4     2006-05-02 13:21:19.907     8800       A           0.0
# ...                       ...      ...     ...           ...
# 59690 2006-04-09 16:47:22.993    19700       A           0.0
# 59691 2006-03-16 16:36:49.443    24600       A           0.0
# 59692 2006-10-04 17:37:16.957    12300       A           0.0
# 59693 2006-05-07 21:51:33.703     5500       A           1.0
# 59694 2006-05-12 20:10:00.250     5500       A           1.0
#
# [59695 rows x 22 columns]

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59695 entries, 0 to 59694
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MEM_ID        59695 non-null  int64
#  1   M_STORE_ID    59695 non-null  int64
#  2   GENDER        59695 non-null  object
#  3   BIRTH_DT      59695 non-null  object
#  4   BIRTH_SL      59695 non-null  object
#  5   ZIP_CD        59695 non-null  object
#  6   RGST_DT       59695 non-null  datetime64[ns]
#  7   VISIT_CNT     59695 non-null  int64
#  8   SALES_AMT     59695 non-null  int64
#  9   LAST_VST_DT   59695 non-null  datetime64[ns]
#  10  USABLE_PNT    59695 non-null  int64
#  11  USED_PNT      59695 non-null  int64
#  12  ACC_PNT       59695 non-null  int64
#  13  USABLE_INIT   59695 non-null  int64
#  14  SMS           59695 non-null  object
#  15  STORE_ID      59695 non-null  int64
#  16  SELL_DT       59695 non-null  datetime64[ns]
#  17  MEMP_STY      59695 non-null  object
#  18  MEMP_DT       59695 non-null  datetime64[ns]
#  19  SELL_AMT      59695 non-null  int64
#  20  MEMP_TP       59695 non-null  object
#  21  STORE_REGION  59695 non-null  float64
# dtypes: datetime64[ns](4), float64(1), int64(10), object(7)
# memory usage: 10.5+ MB

# %%
merged.BIRTH_SL = (merged.BIRTH_SL=='S').astype(int)
merged.BIRTH_SL.value_counts()
# Out:
# 1    49146
# 0    10549
# Name: BIRTH_SL, dtype: int64

# %%
merged.SMS = (merged.SMS=='Y').astype(int)
merged.SMS.value_counts()
# Out:
# 1    58391
# 0     1304
# Name: SMS, dtype: int64

# %%
merged.MEMP_STY = (merged.MEMP_STY=='O').astype(int)
merged.MEMP_STY.value_counts()
# Out:
# 1    58668
# 0     1027
# Name: MEMP_STY, dtype: int64

# %%
apply = np.where(merged['USED_PNT']==0,1,0)
local = merged.columns.get_loc('MEMP_TP')
merged.insert(loc=local, column='MEMP_TP_CODE', value=apply)

merged = merged.drop('MEMP_TP', axis=1)
merged
# Out:
#         MEM_ID  M_STORE_ID   GENDER    BIRTH_DT  BIRTH_SL ZIP_CD  \
# 0          957         543        M           0         1      -
# 1          957         543        M           0         1      -
# 2          957         543        M           0         1      -
# 3         1054         550  UNKNOWN   1968.9.28         0      -
# 4         1054         550  UNKNOWN   1968.9.28         0      -
# ...        ...         ...      ...         ...       ...    ...
# 59690  1427447         825        M           0         1      -
# 59691  1427464         997        F  1983.10.12         0      -
# 59692  1427464         997        F  1983.10.12         0      -
# 59693  1427535       30017        M           0         1      -
# 59694  1427535       30017        M           0         1      -
#
#                       RGST_DT  VISIT_CNT  SALES_AMT             LAST_VST_DT  \
# 0     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 1     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 2     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 3     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# 4     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# ...                       ...        ...        ...                     ...
# 59690 2006-03-06 01:00:01.187          1      26100 2006-04-09 16:47:22.993
# 59691 2006-03-06 01:00:01.187          2      36900 2006-10-04 17:37:16.957
# 59692 2006-03-06 01:00:01.187          2      36900 2006-10-04 17:37:16.957
# 59693 2006-03-07 01:00:00.560          2      11000 2006-05-12 20:10:00.250
# 59694 2006-03-07 01:00:00.560          2      11000 2006-05-12 20:10:00.250
#
#        ...  ACC_PNT  USABLE_INIT  SMS  STORE_ID    SELL_DT  MEMP_STY  \
# 0      ...     1778         1628    1      2031 2007-08-30         1
# 1      ...     1778         1628    1      3123 2007-08-17         1
# 2      ...     1778         1628    1       554 2006-10-04         1
# 3      ...    29158          846    0       550 2006-05-02         1
# 4      ...    29158          846    0       550 2006-05-02         1
# ...    ...      ...          ...  ...       ...        ...       ...
# 59690  ...      522            0    1       825 2006-04-09         1
# 59691  ...      856            0    1       997 2006-03-16         1
# 59692  ...      856            0    1       997 2006-10-04         1
# 59693  ...      338            0    1      3125 2006-05-07         1
# 59694  ...      338            0    1      3125 2006-05-12         1
#
#                       MEMP_DT  SELL_AMT MEMP_TP_CODE  STORE_REGION
# 0     2007-08-30 20:34:42.827      3000            1           0.0
# 1     2007-08-17 18:53:58.937      3000            1           0.0
# 2     2006-10-04 23:55:07.240      1500            1           0.0
# 3     2006-05-02 13:20:35.643    134000            1           0.0
# 4     2006-05-02 13:21:19.907      8800            1           0.0
# ...                       ...       ...          ...           ...
# 59690 2006-04-09 16:47:22.993     19700            1           0.0
# 59691 2006-03-16 16:36:49.443     24600            1           0.0
# 59692 2006-10-04 17:37:16.957     12300            1           0.0
# 59693 2006-05-07 21:51:33.703      5500            1           1.0
# 59694 2006-05-12 20:10:00.250      5500            1           1.0
#
# [59695 rows x 22 columns]

# %%
merged = merged.assign(RGSTyear=merged.RGST_DT.dt.year,
                      LASTyear=merged.LAST_VST_DT.dt.year,
                      SELLyear=merged.SELL_DT.dt.year,
                      MEMPyear=merged.MEMP_DT.dt.year)
merged
# Out:
#         MEM_ID  M_STORE_ID   GENDER    BIRTH_DT  BIRTH_SL ZIP_CD  \
# 0          957         543        M           0         1      -
# 1          957         543        M           0         1      -
# 2          957         543        M           0         1      -
# 3         1054         550  UNKNOWN   1968.9.28         0      -
# 4         1054         550  UNKNOWN   1968.9.28         0      -
# ...        ...         ...      ...         ...       ...    ...
# 59690  1427447         825        M           0         1      -
# 59691  1427464         997        F  1983.10.12         0      -
# 59692  1427464         997        F  1983.10.12         0      -
# 59693  1427535       30017        M           0         1      -
# 59694  1427535       30017        M           0         1      -
#
#                       RGST_DT  VISIT_CNT  SALES_AMT             LAST_VST_DT  \
# 0     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 1     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 2     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 3     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# 4     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# ...                       ...        ...        ...                     ...
# 59690 2006-03-06 01:00:01.187          1      26100 2006-04-09 16:47:22.993
# 59691 2006-03-06 01:00:01.187          2      36900 2006-10-04 17:37:16.957
# 59692 2006-03-06 01:00:01.187          2      36900 2006-10-04 17:37:16.957
# 59693 2006-03-07 01:00:00.560          2      11000 2006-05-12 20:10:00.250
# 59694 2006-03-07 01:00:00.560          2      11000 2006-05-12 20:10:00.250
#
#        ...    SELL_DT  MEMP_STY                 MEMP_DT  SELL_AMT  \
# 0      ... 2007-08-30         1 2007-08-30 20:34:42.827      3000
# 1      ... 2007-08-17         1 2007-08-17 18:53:58.937      3000
# 2      ... 2006-10-04         1 2006-10-04 23:55:07.240      1500
# 3      ... 2006-05-02         1 2006-05-02 13:20:35.643    134000
# 4      ... 2006-05-02         1 2006-05-02 13:21:19.907      8800
# ...    ...        ...       ...                     ...       ...
# 59690  ... 2006-04-09         1 2006-04-09 16:47:22.993     19700
# 59691  ... 2006-03-16         1 2006-03-16 16:36:49.443     24600
# 59692  ... 2006-10-04         1 2006-10-04 17:37:16.957     12300
# 59693  ... 2006-05-07         1 2006-05-07 21:51:33.703      5500
# 59694  ... 2006-05-12         1 2006-05-12 20:10:00.250      5500
#
#        MEMP_TP_CODE  STORE_REGION RGSTyear  LASTyear SELLyear  MEMPyear
# 0                 1           0.0     2006      2007     2007      2007
# 1                 1           0.0     2006      2007     2007      2007
# 2                 1           0.0     2006      2007     2006      2006
# 3                 1           0.0     2006      2007     2006      2006
# 4                 1           0.0     2006      2007     2006      2006
# ...             ...           ...      ...       ...      ...       ...
# 59690             1           0.0     2006      2006     2006      2006
# 59691             1           0.0     2006      2006     2006      2006
# 59692             1           0.0     2006      2006     2006      2006
# 59693             1           1.0     2006      2006     2006      2006
# 59694             1           1.0     2006      2006     2006      2006
#
# [59695 rows x 26 columns]

# %%
# Label encoding
'''from sklearn.preprocessing import LabelEncoder

cat_features = ['RGST_DT','LAST_VST_DT','MEMP_DT']
encoder = LabelEncoder()
encoded = merged[cat_features].apply(encoder.fit_transform)
encoded'''
# Out:
# "from sklearn.preprocessing import LabelEncoder\n\ncat_features = ['RGST_DT','LAST_VST_DT','MEMP_DT']\nencoder = LabelEncoder()\nencoded = merged[cat_features].apply(encoder.fit_transform)\nencoded"

# %%
cols = ['BIRTH_DT','ZIP_CD']
merged[cols] = merged[cols].apply(lambda x: x.astype('category').cat.codes)
merged
# Out:
#         MEM_ID  M_STORE_ID   GENDER  BIRTH_DT  BIRTH_SL  ZIP_CD  \
# 0          957         543        M         0         1       0
# 1          957         543        M         0         1       0
# 2          957         543        M         0         1       0
# 3         1054         550  UNKNOWN       647         0       0
# 4         1054         550  UNKNOWN       647         0       0
# ...        ...         ...      ...       ...       ...     ...
# 59690  1427447         825        M         0         1       0
# 59691  1427464         997        F      2833         0       0
# 59692  1427464         997        F      2833         0       0
# 59693  1427535       30017        M         0         1       0
# 59694  1427535       30017        M         0         1       0
#
#                       RGST_DT  VISIT_CNT  SALES_AMT             LAST_VST_DT  \
# 0     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 1     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 2     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 3     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# 4     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# ...                       ...        ...        ...                     ...
# 59690 2006-03-06 01:00:01.187          1      26100 2006-04-09 16:47:22.993
# 59691 2006-03-06 01:00:01.187          2      36900 2006-10-04 17:37:16.957
# 59692 2006-03-06 01:00:01.187          2      36900 2006-10-04 17:37:16.957
# 59693 2006-03-07 01:00:00.560          2      11000 2006-05-12 20:10:00.250
# 59694 2006-03-07 01:00:00.560          2      11000 2006-05-12 20:10:00.250
#
#        ...    SELL_DT  MEMP_STY                 MEMP_DT  SELL_AMT  \
# 0      ... 2007-08-30         1 2007-08-30 20:34:42.827      3000
# 1      ... 2007-08-17         1 2007-08-17 18:53:58.937      3000
# 2      ... 2006-10-04         1 2006-10-04 23:55:07.240      1500
# 3      ... 2006-05-02         1 2006-05-02 13:20:35.643    134000
# 4      ... 2006-05-02         1 2006-05-02 13:21:19.907      8800
# ...    ...        ...       ...                     ...       ...
# 59690  ... 2006-04-09         1 2006-04-09 16:47:22.993     19700
# 59691  ... 2006-03-16         1 2006-03-16 16:36:49.443     24600
# 59692  ... 2006-10-04         1 2006-10-04 17:37:16.957     12300
# 59693  ... 2006-05-07         1 2006-05-07 21:51:33.703      5500
# 59694  ... 2006-05-12         1 2006-05-12 20:10:00.250      5500
#
#        MEMP_TP_CODE  STORE_REGION RGSTyear  LASTyear SELLyear  MEMPyear
# 0                 1           0.0     2006      2007     2007      2007
# 1                 1           0.0     2006      2007     2007      2007
# 2                 1           0.0     2006      2007     2006      2006
# 3                 1           0.0     2006      2007     2006      2006
# 4                 1           0.0     2006      2007     2006      2006
# ...             ...           ...      ...       ...      ...       ...
# 59690             1           0.0     2006      2006     2006      2006
# 59691             1           0.0     2006      2006     2006      2006
# 59692             1           0.0     2006      2006     2006      2006
# 59693             1           1.0     2006      2006     2006      2006
# 59694             1           1.0     2006      2006     2006      2006
#
# [59695 rows x 26 columns]

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59695 entries, 0 to 59694
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MEM_ID        59695 non-null  int64
#  1   M_STORE_ID    59695 non-null  int64
#  2   GENDER        59695 non-null  object
#  3   BIRTH_DT      59695 non-null  int16
#  4   BIRTH_SL      59695 non-null  int64
#  5   ZIP_CD        59695 non-null  int16
#  6   RGST_DT       59695 non-null  datetime64[ns]
#  7   VISIT_CNT     59695 non-null  int64
#  8   SALES_AMT     59695 non-null  int64
#  9   LAST_VST_DT   59695 non-null  datetime64[ns]
#  10  USABLE_PNT    59695 non-null  int64
#  11  USED_PNT      59695 non-null  int64
#  12  ACC_PNT       59695 non-null  int64
#  13  USABLE_INIT   59695 non-null  int64
#  14  SMS           59695 non-null  int64
#  15  STORE_ID      59695 non-null  int64
#  16  SELL_DT       59695 non-null  datetime64[ns]
#  17  MEMP_STY      59695 non-null  int64
#  18  MEMP_DT       59695 non-null  datetime64[ns]
#  19  SELL_AMT      59695 non-null  int64
#  20  MEMP_TP_CODE  59695 non-null  int64
#  21  STORE_REGION  59695 non-null  float64
#  22  RGSTyear      59695 non-null  int64
#  23  LASTyear      59695 non-null  int64
#  24  SELLyear      59695 non-null  int64
#  25  MEMPyear      59695 non-null  int64
# dtypes: datetime64[ns](4), float64(1), int16(2), int64(18), object(1)
# memory usage: 11.6+ MB

# %% [markdown]
# ### 학습할 데이터와 예측할 데이터 나누기

# %%
train = merged.GENDER!='UNKNOWN'
train_df = merged[train]
train_df.GENDER = (train_df.GENDER=='M').astype(int)
train_df
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#         MEM_ID  M_STORE_ID  GENDER  BIRTH_DT  BIRTH_SL  ZIP_CD  \
# 0          957         543       1         0         1       0
# 1          957         543       1         0         1       0
# 2          957         543       1         0         1       0
# 8         1067         550       1         0         1       0
# 9         1068         543       1         0         1       0
# ...        ...         ...     ...       ...       ...     ...
# 59690  1427447         825       1         0         1       0
# 59691  1427464         997       0      2833         0       0
# 59692  1427464         997       0      2833         0       0
# 59693  1427535       30017       1         0         1       0
# 59694  1427535       30017       1         0         1       0
#
#                       RGST_DT  VISIT_CNT  SALES_AMT             LAST_VST_DT  \
# 0     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 1     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 2     2006-02-04 11:51:08.233          3      88900 2007-08-30 20:34:42.827
# 8     2006-02-04 11:51:08.233          1     199800 2006-09-16 21:05:11.383
# 9     2006-02-04 11:51:08.233          9     115200 2007-11-07 18:08:30.587
# ...                       ...        ...        ...                     ...
# 59690 2006-03-06 01:00:01.187          1      26100 2006-04-09 16:47:22.993
# 59691 2006-03-06 01:00:01.187          2      36900 2006-10-04 17:37:16.957
# 59692 2006-03-06 01:00:01.187          2      36900 2006-10-04 17:37:16.957
# 59693 2006-03-07 01:00:00.560          2      11000 2006-05-12 20:10:00.250
# 59694 2006-03-07 01:00:00.560          2      11000 2006-05-12 20:10:00.250
#
#        ...    SELL_DT  MEMP_STY                 MEMP_DT  SELL_AMT  \
# 0      ... 2007-08-30         1 2007-08-30 20:34:42.827      3000
# 1      ... 2007-08-17         1 2007-08-17 18:53:58.937      3000
# 2      ... 2006-10-04         1 2006-10-04 23:55:07.240      1500
# 8      ... 2006-09-16         1 2006-09-16 21:05:11.383      7700
# 9      ... 2006-08-10         1 2006-08-10 17:49:21.713      8800
# ...    ...        ...       ...                     ...       ...
# 59690  ... 2006-04-09         1 2006-04-09 16:47:22.993     19700
# 59691  ... 2006-03-16         1 2006-03-16 16:36:49.443     24600
# 59692  ... 2006-10-04         1 2006-10-04 17:37:16.957     12300
# 59693  ... 2006-05-07         1 2006-05-07 21:51:33.703      5500
# 59694  ... 2006-05-12         1 2006-05-12 20:10:00.250      5500
#
#        MEMP_TP_CODE  STORE_REGION RGSTyear  LASTyear SELLyear  MEMPyear
# 0                 1           0.0     2006      2007     2007      2007
# 1                 1           0.0     2006      2007     2007      2007
# 2                 1           0.0     2006      2007     2006      2006
# 8                 1           0.0     2006      2006     2006      2006
# 9                 1           0.0     2006      2007     2006      2006
# ...             ...           ...      ...       ...      ...       ...
# 59690             1           0.0     2006      2006     2006      2006
# 59691             1           0.0     2006      2006     2006      2006
# 59692             1           0.0     2006      2006     2006      2006
# 59693             1           1.0     2006      2006     2006      2006
# 59694             1           1.0     2006      2006     2006      2006
#
# [39255 rows x 26 columns]

# %%
pred = merged.GENDER=='UNKNOWN'
pred_df = merged[pred].sort_values('MEM_ID')
pred_df
# Out:
#         MEM_ID  M_STORE_ID   GENDER  BIRTH_DT  BIRTH_SL  ZIP_CD  \
# 3         1054         550  UNKNOWN       647         0       0
# 4         1054         550  UNKNOWN       647         0       0
# 5         1054         550  UNKNOWN       647         0       0
# 6         1054         550  UNKNOWN       647         0       0
# 7         1054         550  UNKNOWN       647         0       0
# ...        ...         ...      ...       ...       ...     ...
# 59673  1427218         997  UNKNOWN       506         0       0
# 59674  1427218         997  UNKNOWN       506         0       0
# 59675  1427218         997  UNKNOWN       506         0       0
# 59676  1427218         997  UNKNOWN       506         0       0
# 59686  1427418         997  UNKNOWN      3241         0       0
#
#                       RGST_DT  VISIT_CNT  SALES_AMT             LAST_VST_DT  \
# 3     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# 4     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# 5     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# 6     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# 7     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# ...                       ...        ...        ...                     ...
# 59673 2006-03-05 01:00:05.403          6     199300 2007-09-18 15:48:22.983
# 59674 2006-03-05 01:00:05.403          6     199300 2007-09-18 15:48:22.983
# 59675 2006-03-05 01:00:05.403          6     199300 2007-09-18 15:48:22.983
# 59676 2006-03-05 01:00:05.403          6     199300 2007-09-18 15:48:22.983
# 59686 2006-03-06 01:00:01.187          1      27900 2007-06-20 13:29:28.427
#
#        ...    SELL_DT  MEMP_STY                 MEMP_DT  SELL_AMT  \
# 3      ... 2006-05-02         1 2006-05-02 13:20:35.643    134000
# 4      ... 2006-05-02         1 2006-05-02 13:21:19.907      8800
# 5      ... 2007-10-16         1 2007-10-16 12:55:20.137     17600
# 6      ... 2006-03-15         1 2006-03-15 21:31:08.877     15400
# 7      ... 2006-10-26         1 2006-10-26 18:22:49.353     14800
# ...    ...        ...       ...                     ...       ...
# 59673  ... 2007-02-26         1 2007-02-26 17:52:08.240     34400
# 59674  ... 2007-09-18         1 2007-09-18 15:48:22.983     26800
# 59675  ... 2006-03-09         1 2006-03-09 14:56:00.570      7900
# 59676  ... 2006-12-06         1 2006-12-06 21:06:42.717     25800
# 59686  ... 2007-06-20         1 2007-06-20 13:29:28.427     21800
#
#        MEMP_TP_CODE  STORE_REGION RGSTyear  LASTyear SELLyear  MEMPyear
# 3                 1           0.0     2006      2007     2006      2006
# 4                 1           0.0     2006      2007     2006      2006
# 5                 1           0.0     2006      2007     2007      2007
# 6                 1           0.0     2006      2007     2006      2006
# 7                 1           0.0     2006      2007     2006      2006
# ...             ...           ...      ...       ...      ...       ...
# 59673             1           0.0     2006      2007     2007      2007
# 59674             1           0.0     2006      2007     2007      2007
# 59675             1           0.0     2006      2007     2006      2006
# 59676             1           0.0     2006      2007     2006      2006
# 59686             1           0.0     2006      2007     2007      2007
#
# [20440 rows x 26 columns]

# %%
'''sns.heatmap(train_df[["GENDER","VISIT_CNT","SALES_AMT","BIRTH_SL_CODE","USABLE_PNT","USED_PNT","ACC_PNT",
                     "USABLE_INIT","SMS_CODE","STORE_ID","SELL_AMT"]]\
            .corr(),annot=True, fmt = ".2f", cmap = "coolwarm")'''
# Out:
# 'sns.heatmap(train_df[["GENDER","VISIT_CNT","SALES_AMT","BIRTH_SL_CODE","USABLE_PNT","USED_PNT","ACC_PNT",\n                     "USABLE_INIT","SMS_CODE","STORE_ID","SELL_AMT"]]            .corr(),annot=True, fmt = ".2f", cmap = "coolwarm")'

# %%
train_df.corr()
# Out:
#                 MEM_ID  M_STORE_ID    GENDER  BIRTH_DT  BIRTH_SL    ZIP_CD  \
# MEM_ID        1.000000   -0.055260  0.316476 -0.294412 -0.081091 -0.329251
# M_STORE_ID   -0.055260    1.000000 -0.044521 -0.029844 -0.074122 -0.035088
# GENDER        0.316476   -0.044521  1.000000 -0.669926  0.362887 -0.226591
# BIRTH_DT     -0.294412   -0.029844 -0.669926  1.000000 -0.160609  0.229686
# BIRTH_SL     -0.081091   -0.074122  0.362887 -0.160609  1.000000  0.075649
# ZIP_CD       -0.329251   -0.035088 -0.226591  0.229686  0.075649  1.000000
# VISIT_CNT     0.060696   -0.026980  0.142886 -0.130743  0.059873 -0.046588
# SALES_AMT     0.030041   -0.024742  0.138755 -0.142664  0.046216 -0.044040
# USABLE_PNT    0.018662   -0.024760  0.129887 -0.126990  0.051295 -0.039029
# USED_PNT      0.049496   -0.012914  0.091177 -0.104259  0.018737 -0.027331
# ACC_PNT       0.042253   -0.024727  0.143201 -0.148800  0.046158 -0.043090
# USABLE_INIT  -0.134655   -0.014119  0.041361 -0.070986  0.010725  0.001640
# SMS          -0.012073    0.009932 -0.093514  0.065920 -0.045087  0.017053
# STORE_ID      0.014928    0.025726  0.021524 -0.034257  0.034304 -0.008551
# MEMP_STY      0.004806   -0.007063  0.000591  0.001635  0.024779  0.010410
# SELL_AMT      0.020971   -0.002825  0.020566 -0.050965 -0.011925 -0.014095
# MEMP_TP_CODE  0.092368    0.011940  0.090350 -0.003821  0.056754 -0.040637
# STORE_REGION -0.118617   -0.062461 -0.134114  0.120782  0.023133 -0.029154
# RGSTyear           NaN         NaN       NaN       NaN       NaN       NaN
# LASTyear     -0.054877    0.017455 -0.104466  0.032548 -0.043156  0.031393
# SELLyear     -0.039096    0.008200 -0.056706  0.026210 -0.018760  0.019027
# MEMPyear     -0.039003    0.008187 -0.056716  0.026072 -0.018988  0.019027
#
#               VISIT_CNT  SALES_AMT  USABLE_PNT  USED_PNT  ...       SMS  \
# MEM_ID         0.060696   0.030041    0.018662  0.049496  ... -0.012073
# M_STORE_ID    -0.026980  -0.024742   -0.024760 -0.012914  ...  0.009932
# GENDER         0.142886   0.138755    0.129887  0.091177  ... -0.093514
# BIRTH_DT      -0.130743  -0.142664   -0.126990 -0.104259  ...  0.065920
# BIRTH_SL       0.059873   0.046216    0.051295  0.018737  ... -0.045087
# ZIP_CD        -0.046588  -0.044040   -0.039029 -0.027331  ...  0.017053
# VISIT_CNT      1.000000   0.924695    0.943878  0.413209  ... -0.573731
# SALES_AMT      0.924695   1.000000    0.871076  0.669464  ... -0.508166
# USABLE_PNT     0.943878   0.871076    1.000000  0.226961  ... -0.626516
# USED_PNT       0.413209   0.669464    0.226961  1.000000  ... -0.046265
# ACC_PNT        0.894442   0.992436    0.825436  0.737044  ... -0.461493
# USABLE_INIT    0.838068   0.802438    0.893473  0.200238  ... -0.607112
# SMS           -0.573731  -0.508166   -0.626516 -0.046265  ...  1.000000
# STORE_ID      -0.025316  -0.032226   -0.027467 -0.022177  ...  0.025967
# MEMP_STY       0.017557   0.003567    0.018885 -0.013669  ... -0.013873
# SELL_AMT       0.025584   0.127734    0.043297  0.196766  ... -0.000217
# MEMP_TP_CODE  -0.270337  -0.309119   -0.156797 -0.355628  ...  0.102162
# STORE_REGION  -0.054901  -0.056284   -0.045072 -0.042947  ...  0.038350
# RGSTyear            NaN        NaN         NaN       NaN  ...       NaN
# LASTyear       0.118575   0.085237    0.088869  0.039997  ... -0.032818
# SELLyear      -0.007239  -0.023188   -0.017572 -0.013725  ...  0.021076
# MEMPyear      -0.007215  -0.023149   -0.017551 -0.013684  ...  0.021071
#
#               STORE_ID  MEMP_STY  SELL_AMT  MEMP_TP_CODE  STORE_REGION  \
# MEM_ID        0.014928  0.004806  0.020971      0.092368     -0.118617
# M_STORE_ID    0.025726 -0.007063 -0.002825      0.011940     -0.062461
# GENDER        0.021524  0.000591  0.020566      0.090350     -0.134114
# BIRTH_DT     -0.034257  0.001635 -0.050965     -0.003821      0.120782
# BIRTH_SL      0.034304  0.024779 -0.011925      0.056754      0.023133
# ZIP_CD       -0.008551  0.010410 -0.014095     -0.040637     -0.029154
# VISIT_CNT    -0.025316  0.017557  0.025584     -0.270337     -0.054901
# SALES_AMT    -0.032226  0.003567  0.127734     -0.309119     -0.056284
# USABLE_PNT   -0.027467  0.018885  0.043297     -0.156797     -0.045072
# USED_PNT     -0.022177 -0.013669  0.196766     -0.355628     -0.042947
# ACC_PNT      -0.031676  0.005185  0.144184     -0.314841     -0.056259
# USABLE_INIT  -0.029528 -0.000591  0.030350     -0.292584     -0.030524
# SMS           0.025967 -0.013873 -0.000217      0.102162      0.038350
# STORE_ID      1.000000  0.016432 -0.001675      0.011555      0.029696
# MEMP_STY      0.016432  1.000000 -0.045396      0.000720      0.019434
# SELL_AMT     -0.001675 -0.045396  1.000000     -0.065766     -0.007189
# MEMP_TP_CODE  0.011555  0.000720 -0.065766      1.000000     -0.000430
# STORE_REGION  0.029696  0.019434 -0.007189     -0.000430      1.000000
# RGSTyear           NaN       NaN       NaN           NaN           NaN
# LASTyear      0.017432  0.059686  0.003577     -0.194019      0.077541
# SELLyear      0.046095  0.084936  0.003025     -0.024104      0.150512
# MEMPyear      0.046040  0.084888  0.003138     -0.024279      0.150236
#
#               RGSTyear  LASTyear  SELLyear  MEMPyear
# MEM_ID             NaN -0.054877 -0.039096 -0.039003
# M_STORE_ID         NaN  0.017455  0.008200  0.008187
# GENDER             NaN -0.104466 -0.056706 -0.056716
# BIRTH_DT           NaN  0.032548  0.026210  0.026072
# BIRTH_SL           NaN -0.043156 -0.018760 -0.018988
# ZIP_CD             NaN  0.031393  0.019027  0.019027
# VISIT_CNT          NaN  0.118575 -0.007239 -0.007215
# SALES_AMT          NaN  0.085237 -0.023188 -0.023149
# USABLE_PNT         NaN  0.088869 -0.017572 -0.017551
# USED_PNT           NaN  0.039997 -0.013725 -0.013684
# ACC_PNT            NaN  0.084775 -0.020132 -0.020093
# USABLE_INIT        NaN  0.085310 -0.035623 -0.035526
# SMS                NaN -0.032818  0.021076  0.021071
# STORE_ID           NaN  0.017432  0.046095  0.046040
# MEMP_STY           NaN  0.059686  0.084936  0.084888
# SELL_AMT           NaN  0.003577  0.003025  0.003138
# MEMP_TP_CODE       NaN -0.194019 -0.024104 -0.024279
# STORE_REGION       NaN  0.077541  0.150512  0.150236
# RGSTyear           NaN       NaN       NaN       NaN
# LASTyear           NaN  1.000000  0.361207  0.361426
# SELLyear           NaN  0.361207  1.000000  0.999318
# MEMPyear           NaN  0.361426  0.999318  1.000000
#
# [22 rows x 22 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39255 entries, 0 to 59694
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MEM_ID        39255 non-null  int64
#  1   M_STORE_ID    39255 non-null  int64
#  2   GENDER        39255 non-null  int64
#  3   BIRTH_DT      39255 non-null  int16
#  4   BIRTH_SL      39255 non-null  int64
#  5   ZIP_CD        39255 non-null  int16
#  6   RGST_DT       39255 non-null  datetime64[ns]
#  7   VISIT_CNT     39255 non-null  int64
#  8   SALES_AMT     39255 non-null  int64
#  9   LAST_VST_DT   39255 non-null  datetime64[ns]
#  10  USABLE_PNT    39255 non-null  int64
#  11  USED_PNT      39255 non-null  int64
#  12  ACC_PNT       39255 non-null  int64
#  13  USABLE_INIT   39255 non-null  int64
#  14  SMS           39255 non-null  int64
#  15  STORE_ID      39255 non-null  int64
#  16  SELL_DT       39255 non-null  datetime64[ns]
#  17  MEMP_STY      39255 non-null  int64
#  18  MEMP_DT       39255 non-null  datetime64[ns]
#  19  SELL_AMT      39255 non-null  int64
#  20  MEMP_TP_CODE  39255 non-null  int64
#  21  STORE_REGION  39255 non-null  float64
#  22  RGSTyear      39255 non-null  int64
#  23  LASTyear      39255 non-null  int64
#  24  SELLyear      39255 non-null  int64
#  25  MEMPyear      39255 non-null  int64
# dtypes: datetime64[ns](4), float64(1), int16(2), int64(19)
# memory usage: 7.6 MB

# %%
from sklearn.model_selection import train_test_split
feature_data = train_df.drop(['GENDER','MEM_ID','RGST_DT','LAST_VST_DT','SELL_DT','MEMP_DT'],axis=1)
label_data = train_df.GENDER.values

X_train,X_test,y_train,y_test = train_test_split(feature_data,label_data,test_size=.25,random_state=0)

prediction_data = pred_df.drop(['GENDER','MEM_ID','RGST_DT','LAST_VST_DT','SELL_DT','MEMP_DT'],axis=1)

print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (29441, 20) (9814, 20) (29441,) (9814,)

# %%
prediction_data
# Out:
#        M_STORE_ID  BIRTH_DT  BIRTH_SL  ZIP_CD  VISIT_CNT  SALES_AMT  \
# 3             550       647         0       0          5     232900
# 4             550       647         0       0          5     232900
# 5             550       647         0       0          5     232900
# 6             550       647         0       0          5     232900
# 7             550       647         0       0          5     232900
# ...           ...       ...       ...     ...        ...        ...
# 59673         997       506         0       0          6     199300
# 59674         997       506         0       0          6     199300
# 59675         997       506         0       0          6     199300
# 59676         997       506         0       0          6     199300
# 59686         997      3241         0       0          1      27900
#
#        USABLE_PNT  USED_PNT  ACC_PNT  USABLE_INIT  SMS  STORE_ID  MEMP_STY  \
# 3           29158         0    29158          846    0       550         1
# 4           29158         0    29158          846    0       550         1
# 5           29158         0    29158          846    0      1274         1
# 6           29158         0    29158          846    0      1421         1
# 7           29158         0    29158          846    0      1274         1
# ...           ...       ...      ...          ...  ...       ...       ...
# 59673        3986         0     3986            0    1       997         1
# 59674        3986         0     3986            0    1      3977         1
# 59675        3986         0     3986            0    1       997         1
# 59676        3986         0     3986            0    1       997         1
# 59686         558         0      558            0    1       997         1
#
#        SELL_AMT  MEMP_TP_CODE  STORE_REGION  RGSTyear  LASTyear  SELLyear  \
# 3        134000             1           0.0      2006      2007      2006
# 4          8800             1           0.0      2006      2007      2006
# 5         17600             1           0.0      2006      2007      2007
# 6         15400             1           0.0      2006      2007      2006
# 7         14800             1           0.0      2006      2007      2006
# ...         ...           ...           ...       ...       ...       ...
# 59673     34400             1           0.0      2006      2007      2007
# 59674     26800             1           0.0      2006      2007      2007
# 59675      7900             1           0.0      2006      2007      2006
# 59676     25800             1           0.0      2006      2007      2006
# 59686     21800             1           0.0      2006      2007      2007
#
#        MEMPyear
# 3          2006
# 4          2006
# 5          2007
# 6          2006
# 7          2006
# ...         ...
# 59673      2007
# 59674      2007
# 59675      2006
# 59676      2006
# 59686      2007
#
# [20440 rows x 20 columns]

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score, StratifiedShuffleSplit
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
import numpy as np
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import roc_auc_score
from sklearn.dummy import DummyClassifier
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
from sklearn.preprocessing import PolynomialFeatures, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from imblearn.under_sampling import *
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
import glob

kfold = StratifiedKFold(n_splits=5) # 하이퍼 파라미터 지정
n_it = 12

params = {'max_features':list(np.arange(1, train_df.shape[1])), 'bootstrap':[False], 'n_estimators': [50], 'criterion':['gini','entropy']}
model = RandomizedSearchCV(RandomForestClassifier(), param_distributions=params, n_iter=n_it, cv=kfold, scoring='roc_auc',n_jobs=-1, verbose=1)
print('MODELING.............................................................................')
model.fit(feature_data, label_data)
print('========BEST_AUC_SCORE = ', model.best_score_)
model = model.best_estimator_
pred_df.GENDER = model.predict_proba(prediction_data.values)[:,1]
print('COMPLETE')
# Out:
# MODELING.............................................................................
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   23.3s finished
# ========BEST_AUC_SCORE =  0.9567617320990781
# COMPLETE

# %%
y_model = model.predict(X_test)
print("Dummy model:"); print(confusion_matrix(y_test, pred_dummy))
print("LightGBM:"); print(confusion_matrix(y_test, y_model))
# Out:
# Dummy model:
# [[5445    0]
#  [4369    0]]
# LightGBM:
# [[5445    0]
#  [   0 4369]]

# %% [markdown]
# ### Random search AUC

# %%
fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:,1])
auc(fpr, tpr)
# Out:
# 1.0

# %% [markdown]
# ### Define ROC curve drawing fuction

# %%
dummy = DummyClassifier(strategy='most_frequent').fit(X_train, y_train)
pred_dummy = dummy.predict(X_test)

# %%
def plot_roc_curve(fpr, tpr, model, color=None) :
    model = model + ' (auc = %0.3f)' % auc(fpr, tpr)
    plt.plot(fpr, tpr, label=model, color=color)
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.axis([0,1,0,1])
    plt.xlabel('FPR (1 - specificity)')
    plt.ylabel('TPR (recall)')
    plt.title('ROC curve')
    plt.legend(loc="lower right")

# %%
fpr_dummy, tpr_dummy, _ = roc_curve(y_test, 
                                    dummy.predict_proba(X_test)[:,1])
plot_roc_curve(fpr_dummy, tpr_dummy, 'dummy model', 'hotpink')
fpr_tree, tpr_tree, _ = roc_curve(y_test, 
                                  model.predict_proba(X_test)[:,1])
plot_roc_curve(fpr_tree, tpr_tree, 'lightgbm', 'darkgreen')

# %% [markdown]
# - <font color = "#CC3D3D">아래 그림상의 0.95에 가까운 모형성능을 보임<font>

# %% [markdown]
# <font color='green'>
# <p>
# ### ROC & AUC
#
# <img align="left" src="http://drive.google.com/uc?export=view&id=1Htx445FclSqHhhNxPT_uOYQOBiuneWXJ" width=600 height=400>

# %% [markdown]
# ### Random search PR curve

# %%
from sklearn.metrics import precision_recall_curve

def plot_precision_recall_curve(precisions, recalls) :
    plt.plot(recalls, precisions, color='blue')
    plt.axis([0,1,0,1])
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('PR curve')

# %%
precisions, recalls, _ = precision_recall_curve(y_test, 
                                    model.predict_proba(X_test)[:,1])
plot_precision_recall_curve(precisions, recalls)

# %%
final_check = pred_df.copy()

# %%
final_check.GENDER = model.predict(prediction_data.values)

# %%
final_check['GENDER'].value_counts()
# Out:
# 0    10320
# 1    10120
# Name: GENDER, dtype: int64

# %%
final_check = final_check.groupby(['MEM_ID','GENDER']).agg({'SELL_AMT':'count'}).reset_index()

# %%
final_check['GENDER'].value_counts()
# Out:
# 0    1775
# 1    1454
# Name: GENDER, dtype: int64

# %%
pred_df.GENDER = model.predict_proba(prediction_data.values)[:,1]

# %%
pred_df
# Out:
#         MEM_ID  M_STORE_ID  GENDER  BIRTH_DT  BIRTH_SL  ZIP_CD  \
# 3         1054         550    0.34       647         0       0
# 4         1054         550    0.34       647         0       0
# 5         1054         550    0.34       647         0       0
# 6         1054         550    0.34       647         0       0
# 7         1054         550    0.34       647         0       0
# ...        ...         ...     ...       ...       ...     ...
# 59673  1427218         997    0.12       506         0       0
# 59674  1427218         997    0.06       506         0       0
# 59675  1427218         997    0.10       506         0       0
# 59676  1427218         997    0.12       506         0       0
# 59686  1427418         997    0.58      3241         0       0
#
#                       RGST_DT  VISIT_CNT  SALES_AMT             LAST_VST_DT  \
# 3     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# 4     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# 5     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# 6     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# 7     2006-02-04 11:51:08.233          5     232900 2007-10-16 12:55:20.137
# ...                       ...        ...        ...                     ...
# 59673 2006-03-05 01:00:05.403          6     199300 2007-09-18 15:48:22.983
# 59674 2006-03-05 01:00:05.403          6     199300 2007-09-18 15:48:22.983
# 59675 2006-03-05 01:00:05.403          6     199300 2007-09-18 15:48:22.983
# 59676 2006-03-05 01:00:05.403          6     199300 2007-09-18 15:48:22.983
# 59686 2006-03-06 01:00:01.187          1      27900 2007-06-20 13:29:28.427
#
#        ...    SELL_DT  MEMP_STY                 MEMP_DT  SELL_AMT  \
# 3      ... 2006-05-02         1 2006-05-02 13:20:35.643    134000
# 4      ... 2006-05-02         1 2006-05-02 13:21:19.907      8800
# 5      ... 2007-10-16         1 2007-10-16 12:55:20.137     17600
# 6      ... 2006-03-15         1 2006-03-15 21:31:08.877     15400
# 7      ... 2006-10-26         1 2006-10-26 18:22:49.353     14800
# ...    ...        ...       ...                     ...       ...
# 59673  ... 2007-02-26         1 2007-02-26 17:52:08.240     34400
# 59674  ... 2007-09-18         1 2007-09-18 15:48:22.983     26800
# 59675  ... 2006-03-09         1 2006-03-09 14:56:00.570      7900
# 59676  ... 2006-12-06         1 2006-12-06 21:06:42.717     25800
# 59686  ... 2007-06-20         1 2007-06-20 13:29:28.427     21800
#
#        MEMP_TP_CODE  STORE_REGION RGSTyear  LASTyear SELLyear  MEMPyear
# 3                 1           0.0     2006      2007     2006      2006
# 4                 1           0.0     2006      2007     2006      2006
# 5                 1           0.0     2006      2007     2007      2007
# 6                 1           0.0     2006      2007     2006      2006
# 7                 1           0.0     2006      2007     2006      2006
# ...             ...           ...      ...       ...      ...       ...
# 59673             1           0.0     2006      2007     2007      2007
# 59674             1           0.0     2006      2007     2007      2007
# 59675             1           0.0     2006      2007     2006      2006
# 59676             1           0.0     2006      2007     2006      2006
# 59686             1           0.0     2006      2007     2007      2007
#
# [20440 rows x 26 columns]

# %%
final = pred_df.groupby('MEM_ID').agg({'GENDER':'mean'}).reset_index()
final
# Out:
#        MEM_ID    GENDER
# 0        1054  0.340000
# 1        1231  1.000000
# 2        1400  1.000000
# 3        1483  1.000000
# 4        1581  1.000000
# ...       ...       ...
# 3215  1427085  0.100000
# 3216  1427215  0.260000
# 3217  1427216  0.080000
# 3218  1427218  0.113333
# 3219  1427418  0.580000
#
# [3220 rows x 2 columns]

# %%
final.to_csv('output_data2.csv',index=False)
